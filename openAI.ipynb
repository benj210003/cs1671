# %%
# %%capture
# !pip install openai datasets

#FileObject(id='file-Kcqv75PMKRw5rQZr7YW6du', bytes=32551, created_at=1744647640, filename='fine_tuning_data.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

import openai
from openai import OpenAI
from time import sleep
from datasets import load_dataset
from functools import partial

client = OpenAI(
  api_key=OPENAI_API_KEY,
)

# %%
try:
    response = client.files.create(
        file=open("fine_tuning_data.jsonl", "rb"),
        purpose="fine-tune"
    )
    print("Upload successful:", response)
except Exception as e:
    print("Error:", e)
# Out:
# Upload successful: FileObject(id='file-Kcqv75PMKRw5rQZr7YW6du', bytes=32551, created_at=1744647640, filename='fine_tuning_data.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %%
client.fine_tuning.jobs.create(
  training_file="file-Kcqv75PMKRw5rQZr7YW6du",
  model="gpt-3.5-turbo"
)
# Out:
# FineTuningJob(id='ftjob-8zrF7eRpMk1KRBzJzj6Effmu', created_at=1744648317, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs='auto'), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-LwLUJmzbbWA4moR3jW1mob5t', result_files=[], seed=1428419075, status='validating_files', trained_tokens=None, training_file='file-Kcqv75PMKRw5rQZr7YW6du', validation_file=None, estimated_finish=None, integrations=[], metadata=None, method=Method(dpo=None, supervised=MethodSupervised(hyperparameters=MethodSupervisedHyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs='auto')), type='supervised'), user_provided_suffix=None)
