# %%
# %%capture
# !pip install openai datasets

import openai
from openai import OpenAI
from time import sleep
from datasets import load_dataset
from functools import partial

client = OpenAI(
  api_key=OPENAI_API_KEY,
)

# %%
try:
    response = client.files.create(
        file=open("preprocessed_data.jsonl", "rb"),
        purpose="fine-tune"
    )
    print("Upload successful:", response)
except Exception as e:
    print("Error:", e)
# Out:
# Upload successful: FileObject(id='file-Fg2o2YPPMXXCg6WPEgeA9A', bytes=14243180, created_at=1744725282, filename='preprocessed_data.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %%
client.fine_tuning.jobs.create(
  training_file="file-Fg2o2YPPMXXCg6WPEgeA9A",
  model="gpt-3.5-turbo"
)
# Out:
# FineTuningJob(id='ftjob-r0sGHEG4iaq5WyB0gnahc7Va', created_at=1744725443, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs='auto'), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-LwLUJmzbbWA4moR3jW1mob5t', result_files=[], seed=1075177564, status='validating_files', trained_tokens=None, training_file='file-Fg2o2YPPMXXCg6WPEgeA9A', validation_file=None, estimated_finish=None, integrations=[], metadata=None, method=Method(dpo=None, supervised=MethodSupervised(hyperparameters=MethodSupervisedHyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs='auto')), type='supervised'), user_provided_suffix=None)
